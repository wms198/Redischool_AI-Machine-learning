# %%
# !pip install pandas numpy matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (2.3.2)
# Requirement already satisfied: numpy in ./.venv/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.13/site-packages (3.10.6)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.13/site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.13/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.13/site-packages (from matplotlib) (3.2.4)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
# Titanic Dataset Python Basics Review

# Libraries we'll use
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# For pretty plots
# %matplotlib inline

# Set seaborn style
sns.set(style='whitegrid')

# %%
# Load the Titanic dataset
# Make sure the CSV is in the same directory or update the path
df = pd.read_csv("housing-datasets/data.csv")

# Preview the first few rows
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
# Load the Titanic dataset
# Make sure the CSV is in the same directory or update the path
df = pd.read_csv("housing-datasets/fields.csv")

# Preview the first few rows
df
# Out:
#              name                                        description   type  \
# 0              id                                 Unique identifier.    int
# 1            date                           Date the house was sold.    str
# 2           price                                    The sale price.  float
# 3        bedrooms                                Number of bedrooms.    int
# 4       bathrooms                               Number of bathrooms.  float
# 5     sqft_living                Total interior living space (sqft).    int
# 6        sqft_lot                            Total land area (sqft).    int
# 7          floors                                  Number of floors.  float
# 8      waterfront     A binary flag (1 if it has a waterfront view).    int
# 9            view      A rating from 0 to 4 of how good the view is.    int
# 10      condition     A rating from 1 to 5 on the overall condition.    int
# 11          grade  A rating from 1 to 13 on construction/design q...    int
# 12     sqft_above       Square footage of living space above ground.    int
# 13  sqft_basement       Square footage of living space below ground.    int
# 14       yr_built                      The year the house was built.    int
# 15   yr_renovated  The year the house was last renovated (0 if ne...    int
# 16        zipcode                               The 5-digit zipcode.    int
# 17            lat                               Latitude coordinate.  float
# 18           long                              Longitude coordinate.  float
# 19  sqft_living15  The average living space of the 15 nearest nei...    int
# 20     sqft_lot15  The average lot size of the 15 nearest neighbors.    int
#
#         category  is_target
# 0           meta      False
# 1       temporal      False
# 2        outcome       True
# 3       property      False
# 4       property      False
# 5       property      False
# 6       property      False
# 7       property      False
# 8       property      False
# 9        quality      False
# 10       quality      False
# 11       quality      False
# 12      property      False
# 13      property      False
# 14      temporal      False
# 15      temporal      False
# 16      location      False
# 17      location      False
# 18      location      False
# 19  neighborhood      False
# 20  neighborhood      False

# %%
corr = df.corr(numeric_only=True)
# Heatmap
plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
